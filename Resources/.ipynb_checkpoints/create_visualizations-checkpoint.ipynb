# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
weather_data = pd.read_csv('weather_data.csv')
weather_data.head()
# Out:
#              city  latitude (°N)  longitude (°E)  temperature (°F)  \
# 0  Hambantota, LK       6.124913       81.124256             77.32
# 1      Bagula, IN      23.333869       88.642096             84.90
# 2       Airai, PW       7.359934      134.560115             79.20
# 3        Tual, ID      -5.644309      132.741682             79.34
# 4  Isla Vista, US      34.411513     -119.856213             80.08
#
#    humidity (%)  cloudiness (%)  wind speed (mph)
# 0           100              20              5.75
# 1            74             100              3.18
# 2            83              75              4.61
# 3            82             100             21.56
# 4            59              74              4.18

# %%
weather_data.to_html(buf='data.txt', encoding='utf-8')

# %%
def scatter(df, colx, coly, path=''):
    plt.scatter(df[colx], df[coly])
    namex = colx.split(' ')
    namex.pop()
    namex = ' '.join(namex)
    namey = coly.split(' ')
    namey.pop()
    namey = ' '.join(namey)
    path = f'{path}/{namey}_vs_{namex}'
    plt.title(f'{namey.title()} vs {namex.title()}')
    plt.xlabel(colx.title())
    plt.ylabel(coly.title())
    plt.savefig(path)
    plt.show()

# %%
scatter(weather_data, 'latitude (°N)', 'temperature (°F)', path='../assets/images')
scatter(weather_data, 'latitude (°N)', 'humidity (%)', path='../assets/images')
scatter(weather_data, 'latitude (°N)', 'cloudiness (%)', path='../assets/images')
scatter(weather_data, 'latitude (°N)', 'wind speed (mph)', path='../assets/images')
